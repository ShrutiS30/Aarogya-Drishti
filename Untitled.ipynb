# %%
import pandas as pd

df = pd.read_excel("FitnessTracker.xlsx")
df.head()
# Out:
#    User_ID      Full Name       Date  Age  Gender  Height (cm)  Weight (kg)  \
# 0        1  Sara Martinez 2023-01-01   19  Female          191           80
# 1        1  Sara Martinez 2023-01-02   19  Female          191           80
# 2        1  Sara Martinez 2023-01-03   19  Female          191           80
# 3        1  Sara Martinez 2023-01-04   19  Female          191           80
# 4        1  Sara Martinez 2023-01-05   19  Female          191           80
#
#    Steps_Taken  Calories_Burned  Hours_Slept  Water_Intake (Liters)  \
# 0        11405             1862     7.021201               3.440508
# 1         7010             1806          NaN               3.103590
# 2        18942             2274     8.167817               3.814843
# 3        13778             2656     7.453552               3.508636
# 4        10247             3571     5.132654                    NaN
#
#    Active_Minutes  Heart_Rate (bpm) Workout_Type  Stress_Level (1-10)     Mood
# 0            80.0              84.0         Yoga                    2    Happy
# 1            47.0              72.0       Cardio                    9  Neutral
# 2            46.0              85.0         Yoga                    6      Sad
# 3           105.0              77.0         Yoga                    2      Sad
# 4            53.0              61.0         Yoga                    8      Sad

# %%
df.shape
# Out:
# (36500, 16)

# %%
df.columns
# Out:
# Index(['User_ID', 'Full Name', 'Date', 'Age', 'Gender', 'Height (cm)',
#        'Weight (kg)', 'Steps_Taken', 'Calories_Burned', 'Hours_Slept',
#        'Water_Intake (Liters)', 'Active_Minutes', 'Heart_Rate (bpm)',
#        'Workout_Type', 'Stress_Level (1-10)', 'Mood'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36500 entries, 0 to 36499
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   User_ID                36500 non-null  int64
#  1   Full Name              36500 non-null  object
#  2   Date                   36500 non-null  datetime64[ns]
#  3   Age                    36500 non-null  int64
#  4   Gender                 36500 non-null  object
#  5   Height (cm)            36500 non-null  int64
#  6   Weight (kg)            36500 non-null  int64
#  7   Steps_Taken            36500 non-null  int64
#  8   Calories_Burned        36500 non-null  int64
#  9   Hours_Slept            32841 non-null  float64
#  10  Water_Intake (Liters)  31099 non-null  float64
#  11  Active_Minutes         34633 non-null  float64
#  12  Heart_Rate (bpm)       34668 non-null  float64
#  13  Workout_Type           27308 non-null  object
#  14  Stress_Level (1-10)    36500 non-null  int64
#  15  Mood                   36500 non-null  object
# dtypes: datetime64[ns](1), float64(4), int64(7), object(4)
# memory usage: 4.5+ MB

# %%
df.isnull().sum()
# Out:
# User_ID                     0
# Full Name                   0
# Date                        0
# Age                         0
# Gender                      0
# Height (cm)                 0
# Weight (kg)                 0
# Steps_Taken                 0
# Calories_Burned             0
# Hours_Slept              3659
# Water_Intake (Liters)    5401
# Active_Minutes           1867
# Heart_Rate (bpm)         1832
# Workout_Type             9192
# Stress_Level (1-10)         0
# Mood                        0
# dtype: int64

# %%
# Numerical columns: fill missing values with median
num_cols = [
    'Hours_Slept',
    'Water_Intake (Liters)',
    'Active_Minutes',
    'Heart_Rate (bpm)'
]

for col in num_cols:
    df[col] = df[col].fillna(df[col].median())

# Categorical column: fill missing values with "Unknown"
df['Workout_Type'] = df['Workout_Type'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# User_ID                  0
# Full Name                0
# Date                     0
# Age                      0
# Gender                   0
# Height (cm)              0
# Weight (kg)              0
# Steps_Taken              0
# Calories_Burned          0
# Hours_Slept              0
# Water_Intake (Liters)    0
# Active_Minutes           0
# Heart_Rate (bpm)         0
# Workout_Type             0
# Stress_Level (1-10)      0
# Mood                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#             User_ID                           Date           Age  \
# count  36500.000000                          36500  36500.000000
# mean      50.500000  2023-07-02 00:00:00.000000256     43.160000
# min        1.000000            2023-01-01 00:00:00     19.000000
# 25%       25.750000            2023-04-02 00:00:00     29.000000
# 50%       50.500000            2023-07-02 00:00:00     44.000000
# 75%       75.250000            2023-10-01 00:00:00     56.250000
# max      100.000000            2023-12-31 00:00:00     63.000000
# std       28.866465                            NaN     13.674046
#
#         Height (cm)   Weight (kg)   Steps_Taken  Calories_Burned  \
# count  36500.000000  36500.000000  36500.000000     36500.000000
# mean     172.690000     85.830000  11035.111973      2747.735452
# min      150.000000     51.000000   2000.000000      1500.000000
# 25%      160.000000     68.000000   6522.750000      2119.000000
# 50%      173.000000     86.000000  11042.000000      2748.000000
# 75%      181.000000    107.000000  15561.500000      3376.000000
# max      199.000000    118.000000  19999.000000      3999.000000
# std       14.433974     21.567426   5203.268097       723.854309
#
#         Hours_Slept  Water_Intake (Liters)  Active_Minutes  Heart_Rate (bpm)  \
# count  36500.000000           36500.000000    36500.000000      36500.000000
# mean       6.493056               2.742036       74.353425         79.595671
# min        4.000329               1.500416       30.000000         60.000000
# 25%        5.380170               2.228995       53.000000         70.000000
# 50%        6.500790               2.739198       74.000000         80.000000
# 75%        7.578819               3.253690       96.000000         89.000000
# max        8.999341               3.999981      119.000000         99.000000
# std        1.363696               0.664843       25.338538         11.240155
#
#        Stress_Level (1-10)
# count         36500.000000
# mean              5.499260
# min               1.000000
# 25%               3.000000
# 50%               6.000000
# 75%               8.000000
# max              10.000000
# std               2.881435

# %%
df.describe(include='object')
# Out:
#            Full Name Gender Workout_Type   Mood
# count          36500  36500        36500  36500
# unique            59      3            4      4
# top     David Garcia   Male         Yoga    Sad
# freq            1460  14600         9222   9284

# %%
# Calculate BMI
df['BMI'] = df['Weight (kg)'] / ((df['Height (cm)'] / 100) ** 2)

# Extract Month from Date
df['Month'] = df['Date'].dt.month_name()

# Extract Day Name
df['Day'] = df['Date'].dt.day_name()

# %%
df[['Date', 'BMI', 'Month', 'Day']].head()
# Out:
#         Date        BMI    Month        Day
# 0 2023-01-01  21.929223  January     Sunday
# 1 2023-01-02  21.929223  January     Monday
# 2 2023-01-03  21.929223  January    Tuesday
# 3 2023-01-04  21.929223  January  Wednesday
# 4 2023-01-05  21.929223  January   Thursday

# %%
import matplotlib.pyplot as plt

daily_steps = df.groupby('Date')['Steps_Taken'].mean()

plt.figure(figsize=(12, 5))
plt.plot(daily_steps.index, daily_steps.values)
plt.title('Average Daily Steps Over Time')
plt.xlabel('Date')
plt.ylabel('Average Steps')
plt.show()

# %%
avg_calories = df.groupby('Workout_Type')['Calories_Burned'].mean()

plt.figure(figsize=(8, 5))
avg_calories.plot(kind='bar')
plt.title('Average Calories Burned by Workout Type')
plt.xlabel('Workout Type')
plt.ylabel('Average Calories Burned')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(df['Active_Minutes'], df['Steps_Taken'], alpha=0.3)
plt.title('Steps Taken vs Active Minutes')
plt.xlabel('Active Minutes')
plt.ylabel('Steps Taken')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

features = df[
    [
        'Steps_Taken',
        'Calories_Burned',
        'Hours_Slept',
        'Active_Minutes',
        'Stress_Level (1-10)'
    ]
]

scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

print(scaled_features.shape)
# Out:
# (36500, 5)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(
    n_clusters=3,
    random_state=42,
    n_init=10
)

df['Cluster'] = kmeans.fit_predict(scaled_features)

df[['Steps_Taken', 'Calories_Burned', 'Cluster']].head()
# Out:
#    Steps_Taken  Calories_Burned  Cluster
# 0        11405             1862        1
# 1         7010             1806        0
# 2        18942             2274        2
# 3        13778             2656        1
# 4        10247             3571        0

# %%
df[['Steps_Taken', 'Calories_Burned', 'Hours_Slept',
    'Active_Minutes', 'Stress_Level (1-10)', 'Cluster']].head(10)
# Out:
#    Steps_Taken  Calories_Burned  Hours_Slept  Active_Minutes  \
# 0        11405             1862     7.021201            80.0
# 1         7010             1806     6.500790            47.0
# 2        18942             2274     8.167817            46.0
# 3        13778             2656     7.453552           105.0
# 4        10247             3571     5.132654            53.0
# 5         5081             2165     6.500790            73.0
# 6        12078             1756     8.983713            34.0
# 7        18323             3167     6.925079           102.0
# 8         2366             2344     5.007600            74.0
# 9        11639             3283     8.619244           115.0
#
#    Stress_Level (1-10)  Cluster
# 0                    2        1
# 1                    9        0
# 2                    6        2
# 3                    2        1
# 4                    8        0
# 5                   10        0
# 6                    1        1
# 7                    3        2
# 8                    5        1
# 9                    8        0

# %%
cluster_summary = df.groupby('Cluster')[
    [
        'Steps_Taken',
        'Calories_Burned',
        'Hours_Slept',
        'Active_Minutes',
        'Stress_Level (1-10)'
    ]
].mean().round(2)

cluster_summary
# Out:
#          Steps_Taken  Calories_Burned  Hours_Slept  Active_Minutes  \
# Cluster
# 0            7779.69          2748.37         6.50           73.99
# 1            7656.10          2740.09         6.49           73.94
# 2           16484.47          2753.44         6.49           74.99
#
#          Stress_Level (1-10)
# Cluster
# 0                       8.20
# 1                       2.80
# 2                       5.46

# %%
cluster_labels = {
    0: 'High Stress - Moderate Activity',
    1: 'Low Stress - Moderate Activity',
    2: 'Highly Active'
}

df['Activity_Segment'] = df['Cluster'].map(cluster_labels)

df[['Cluster', 'Activity_Segment']].head(10)
# Out:
#    Cluster                 Activity_Segment
# 0        1   Low Stress - Moderate Activity
# 1        0  High Stress - Moderate Activity
# 2        2                    Highly Active
# 3        1   Low Stress - Moderate Activity
# 4        0  High Stress - Moderate Activity
# 5        0  High Stress - Moderate Activity
# 6        1   Low Stress - Moderate Activity
# 7        2                    Highly Active
# 8        1   Low Stress - Moderate Activity
# 9        0  High Stress - Moderate Activity

# %%
df['Activity_Segment'].value_counts()
# Out:
# Activity_Segment
# Highly Active                      13810
# High Stress - Moderate Activity    11441
# Low Stress - Moderate Activity     11249
# Name: count, dtype: int64

# %%
df.to_excel("HealthPulse_Final_Data.xlsx", index=False)

# %%
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
import plotly.express as px

# --------------------------------------------------
# PAGE CONFIGURATION
# --------------------------------------------------

st.set_page_config(
    page_title="Aarogya Drishti",
    layout="wide",
    initial_sidebar_state="collapsed"
)

# --------------------------------------------------
# CUSTOM CSS
# --------------------------------------------------

st.markdown("""
<style>

.stApp {
    background-color: #183563;
}

.block-container {
    padding-top: 2rem;
    padding-bottom: 2rem;
    max-width: 1450px;
}

/* Hide default Streamlit elements */
#MainMenu {
    visibility: hidden;
}

footer {
    visibility: hidden;
}

header {
    visibility: hidden;
}

/* Title */
.main-title {
    color: white;
    font-size: 48px;
    font-family: Georgia, serif;
    font-weight: 700;
    letter-spacing: 1px;
    line-height: 1;
}

.subtitle {
    color: white;
    font-size: 20px;
    font-family: Georgia, serif;
    margin-top: 8px;
    margin-bottom: 25px;
}

/* KPI Cards */
.kpi-card {
    background: linear-gradient(135deg, #f8f8f8, #e6e7eb);
    border-radius: 3px;
    padding: 18px;
    margin-bottom: 14px;
    min-height: 85px;
    box-shadow: 0px 2px 5px rgba(0,0,0,0.18);
}

.kpi-value {
    color: #454545;
    font-size: 28px;
    font-weight: 700;
    line-height: 1.2;
}

.kpi-label {
    color: #666666;
    font-size: 14px;
    margin-top: 5px;
}

/* Make charts fit nicely */
div[data-testid="stPlotlyChart"] {
    background-color: #f4f4f4;
}

</style>
""", unsafe_allow_html=True)


# --------------------------------------------------
# LOAD DATA
# --------------------------------------------------

@st.cache_data
def load_data():
    df = pd.read_csv("HealthPulse_Final_Data.csv")

    df["Date"] = pd.to_datetime(df["Date"])

    return df


df = load_data()


# --------------------------------------------------
# TITLE
# --------------------------------------------------

st.markdown(
    '<div class="main-title">AAROGYA DRISHTI</div>',
    unsafe_allow_html=True
)

st.markdown(
    '<div class="subtitle">Personal Wellness Analytics Dashboard</div>',
    unsafe_allow_html=True
)


# --------------------------------------------------
# MAIN DASHBOARD LAYOUT
# --------------------------------------------------

left_col, right_col = st.columns([1, 4], gap="medium")


# ==================================================
# LEFT SIDE - KPIs
# ==================================================

with left_col:

    # Gender Filter
    st.markdown(
        "<h4 style='color:white; margin-bottom:5px;'>Gender</h4>",
        unsafe_allow_html=True
    )

    gender_options = sorted(df["Gender"].dropna().unique())

    selected_gender = st.radio(
        "",
        gender_options,
        horizontal=True,
        label_visibility="collapsed"
    )

    # Filter data
    filtered_df = df[df["Gender"] == selected_gender].copy()

    # Calculate KPIs
    total_users = filtered_df["User_ID"].nunique()
    total_steps = filtered_df["Steps_Taken"].sum()
    total_calories = filtered_df["Calories_Burned"].sum()
    total_stress = filtered_df["Stress_Level (1-10)"].sum()
    total_sleep = filtered_df["Hours_Slept"].sum()

    # KPI Card Function
    def show_kpi(value, label):

        st.markdown(
            f"""
            <div class="kpi-card">
                <div class="kpi-value">{value}</div>
                <div class="kpi-label">{label}</div>
            </div>
            """,
            unsafe_allow_html=True
        )

    show_kpi(
        f"{total_users}",
        "Number of Users"
    )

    show_kpi(
        f"{total_steps / 1_000_000:.0f}M",
        "Sum of Steps Taken"
    )

    show_kpi(
        f"{total_calories / 1_000_000:.0f}M",
        "Sum of Calories Burned"
    )

    show_kpi(
        f"{total_stress / 1_000:.0f}K",
        "Sum of Stress Level"
    )

    show_kpi(
        f"{total_sleep / 1_000:.2f}K",
        "Sum of Hours Slept"
    )


# ==================================================
# RIGHT SIDE - CHARTS
# ==================================================

with right_col:

    # ----------------------------------------------
    # TOP ROW - THREE CHARTS
    # ----------------------------------------------

    chart1, chart2, chart3 = st.columns(3, gap="small")

    # ==============================================
    # SLEEP VS STRESS LEVEL
    # ==============================================

    with chart1:

        sleep_stress = (
            filtered_df
            .groupby("Stress_Level (1-10)", as_index=False)
            ["Hours_Slept"]
            .mean()
        )

        fig_sleep = px.scatter(
            sleep_stress,
            x="Stress_Level (1-10)",
            y="Hours_Slept",
            title="Sleep v/s Stress Level"
        )

        fig_sleep.update_traces(
            marker=dict(
                size=10,
                color="#234d7d"
            )
        )

        fig_sleep.update_layout(
            height=300,
            paper_bgcolor="#f4f4f4",
            plot_bgcolor="#f4f4f4",
            font=dict(color="#444444"),
            margin=dict(l=40, r=20, t=50, b=40),
            title=dict(
                font=dict(size=17)
            ),
            xaxis_title="Stress Level",
            yaxis_title="Average Hours Slept"
        )

        st.plotly_chart(
            fig_sleep,
            use_container_width=True,
            config={"displayModeBar": False}
        )


    # ==============================================
    # ACTIVITY SEGMENT DISTRIBUTION
    # ==============================================

    with chart2:

        activity_data = (
            filtered_df["Activity_Segment"]
            .value_counts()
            .reset_index()
        )

        activity_data.columns = [
            "Activity Segment",
            "Count"
        ]

        fig_activity = px.pie(
            activity_data,
            names="Activity Segment",
            values="Count",
            hole=0.55,
            title="User by Activity Level",
            color_discrete_sequence=[
                "#1F77B4",
                "#254F7E",
                "#65A9B9"
            ]
        )

        fig_activity.update_layout(
            height=300,
            paper_bgcolor="#f4f4f4",
            font=dict(color="#444444"),
            margin=dict(l=10, r=10, t=50, b=10),
            title=dict(
                font=dict(size=17)
            ),
            legend=dict(
                font=dict(size=10)
            )
        )

        st.plotly_chart(
            fig_activity,
            use_container_width=True,
            config={"displayModeBar": False}
        )


    # ==============================================
    # MONTHLY STEPS TREND
    # ==============================================

    with chart3:

        month_order = [
            "January",
            "February",
            "March",
            "April",
            "May",
            "June",
            "July",
            "August",
            "September",
            "October",
            "November",
            "December"
        ]

        monthly_steps = (
            filtered_df
            .groupby("Month", as_index=False)
            ["Steps_Taken"]
            .sum()
        )

        monthly_steps["Month"] = pd.Categorical(
            monthly_steps["Month"],
            categories=month_order,
            ordered=True
        )

        monthly_steps = monthly_steps.sort_values("Month")

        fig_month = px.line(
            monthly_steps,
            x="Month",
            y="Steps_Taken",
            title="Monthly Steps Trend"
        )

        fig_month.update_traces(
            line=dict(
                color="#234d7d",
                width=3
            ),
            marker=dict(size=6)
        )

        fig_month.update_layout(
            height=300,
            paper_bgcolor="#f4f4f4",
            plot_bgcolor="#f4f4f4",
            font=dict(color="#444444"),
            margin=dict(l=40, r=20, t=50, b=55),
            title=dict(
                font=dict(size=17)
            ),
            xaxis_title="Month",
            yaxis_title="Sum of Steps Taken"
        )

        st.plotly_chart(
            fig_month,
            use_container_width=True,
            config={"displayModeBar": False}
        )


    # ----------------------------------------------
    # BOTTOM ROW
    # ----------------------------------------------

    bottom_left, bottom_right = st.columns([2.2, 1], gap="small")

    # ==============================================
    # AVERAGE STEPS BY WORKOUT
    # ==============================================

    with bottom_left:

        workout_steps = (
            filtered_df
            .groupby("Workout_Type", as_index=False)
            ["Steps_Taken"]
            .mean()
            .sort_values("Steps_Taken")
        )

        fig_workout = px.bar(
            workout_steps,
            x="Steps_Taken",
            y="Workout_Type",
            orientation="h",
            title="Average Steps by Workout"
        )

        fig_workout.update_traces(
            marker_color="#234d7d"
        )

        fig_workout.update_layout(
            height=300,
            paper_bgcolor="#f4f4f4",
            plot_bgcolor="#f4f4f4",
            font=dict(color="#444444"),
            margin=dict(l=50, r=20, t=50, b=40),
            title=dict(
                font=dict(size=17)
            ),
            xaxis_title="Average Steps Taken",
            yaxis_title="Workout Type"
        )

        st.plotly_chart(
            fig_workout,
            use_container_width=True,
            config={"displayModeBar": False}
        )


    # ==============================================
    # GENDER FILTER PANEL
    # ==============================================

    with bottom_right:

        st.markdown(
            """
            <div style="
                background:#f4f4f4;
                padding:20px;
                min-height:300px;
            ">
                <h3 style="
                    color:#444444;
                    margin-bottom:20px;
                ">
                    Gender
                </h3>
            """,
            unsafe_allow_html=True
        )

        st.markdown(
            f"""
            <div style="
                background:#234d7d;
                color:white;
                padding:18px;
                text-align:center;
                font-size:18px;
                font-weight:bold;
                margin-bottom:10px;
            ">
                {selected_gender}
            </div>
            """,
            unsafe_allow_html=True
        )

        st.markdown("</div>", unsafe_allow_html=True)
# Out:
# Writing app.py

# %%
# !pip install streamlit pandas plotly
# Out:
# Requirement already satisfied: streamlit in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (1.51.0)
# Requirement already satisfied: pandas in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (2.3.3)
# Requirement already satisfied: plotly in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (6.3.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (2.3.5)
# Requirement already satisfied: packaging<26,>=20 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow<22,>=7.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: jinja2 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.7.0)
# Requirement already satisfied: colorama in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shrut\music\new folder\anaconda2\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 9048-2C9E
#
#  Directory of C:\Users\shrut\Fitness Tracker Project
#
# 21-08-2026  18:01    <DIR>          .
# 20-08-2026  19:58    <DIR>          ..
# 20-08-2026  20:00    <DIR>          .ipynb_checkpoints
# 21-08-2026  18:01            11,313 app.py
# 20-08-2026  20:03         3,078,156 FitnessTracker.xlsx
# 21-08-2026  06:45         5,974,453 HealthPulse_Final_Data.csv
# 21-08-2026  06:39       355,860,480 HealthPulse_Final_Data.xlsx
# 21-08-2026  07:21             2,552 SQLQuery3.sql
# 21-08-2026  18:01           465,131 Untitled.ipynb
#                6 File(s)    365,392,085 bytes
#                3 Dir(s)   9,682,923,520 bytes free

# %%
# !streamlit run app.py
# Out:
# ^C

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\shrut\Fitness Tracker Project
